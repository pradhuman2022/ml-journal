# %% [markdown]
# # ML Journal — Notes
#
# Running notebook for courses, papers, and experiments.

# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Course Notes

# %% [markdown]
# ## Paper Notes

# %% [markdown]
# ## Experiments
